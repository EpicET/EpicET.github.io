# %% [raw]
# ---
# title: Design and Impact of Automated Decision Systems
# author: Emmanuel Towner
# date: '2025-02-19'
# description: "Blog Post 2"
# format: html
# ---

# %% [markdown]
# # Design and Impact of Automated Decision Systems

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/PhilChodrow/ml-notes/main/data/credit-risk/train.csv"
df_train = pd.read_csv(url)
df_train = df_train[df_train["person_income"] < 1e6] # Remove the really high outlier
df_train = df_train[df_train["person_age"] <= 100] # Remove the really high outlier

# %%
df_train.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          25          43200                  RENT                NaN
# 1          27          98000                  RENT                3.0
# 2          22          36996                  RENT                5.0
# 3          24          26000                  RENT                2.0
# 4          29          53004              MORTGAGE                2.0
#
#        loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0          VENTURE          B       1200           9.91            0
# 1        EDUCATION          C      11750          13.47            0
# 2        EDUCATION          A      10000           7.51            0
# 3          MEDICAL          C       1325          12.87            1
# 4  HOMEIMPROVEMENT          A      15000           9.63            0
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.03                         N                           4
# 1                 0.12                         Y                           6
# 2                 0.27                         N                           4
# 3                 0.05                         N                           4
# 4                 0.28                         N                          10

# %%
df_train = df_train[df_train['person_emp_length'] <= 40]

# %% [markdown]
# ## Data Visualization
#
# ### Figures

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_train, x='loan_intent', y='person_emp_length')
# plt.xticks(rotation=30, ha='right')  # Rotate x-axis labels
# plt.tight_layout()  # Automatically adjust padding to fit elements
plt.show()

# %%
p2 = sns.boxplot(data=df_train, x='loan_intent', y='loan_int_rate', hue='cb_person_default_on_file')

# %%
p4 = sns.barplot(df_train, x="loan_status", y="person_income")

# %%
p5 = sns.scatterplot(df_train, x="person_age", y="loan_amnt", hue="loan_intent")

# %%
p6 = sns.boxplot(df_train, x="loan_intent", y="loan_amnt", hue="loan_intent", legend=False)

# %%
p7 = sns.scatterplot(df_train, y="cb_person_default_on_file", x="person_income")

# %%
sns.FacetGrid(df_train, col= "loan_intent")
